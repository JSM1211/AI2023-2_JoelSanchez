# %% [markdown]
# <a href="https://colab.research.google.com/github/JSM1211/AI2023-2_JoelSanchez/blob/main/Pandas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PANDAS HAS TWO DATA STRUCTER

# %%
import pandas as js

# %% [markdown]
# # *   SERIES

# %%
tmp=js.Series(data=[100,200,300,400],index=['carlos','juan','mario','rosita'])
#first form
print(tmp)
#second form
tmp
# Out:
# carlos    100
# juan      200
# mario     300
# rosita    400
# dtype: int64
# carlos    100
# juan      200
# mario     300
# rosita    400
# dtype: int64

# %%
tmp.shape
# Out:
# (4,)

# %%
print(tmp['mario'])
# Out:
# 300

# %%
print(tmp[-2])
# Out:
# 300

# %%
tmp*2
# Out:
# carlos    200
# juan      400
# mario     600
# rosita    800
# dtype: int64

# %%
print(tmp[[1,2,3]])
print('----------------')
tmp[[1,2,3]]
# Out:
# juan      200
# mario     300
# rosita    400
# dtype: int64
# ----------------
# juan      200
# mario     300
# rosita    400
# dtype: int64

# %%
tmp.index
# Out:
# Index(['carlos', 'juan', 'mario', 'rosita'], dtype='object')

# %%
# create a dictionary with items
my_dictionary = {"name": "John", "age": 25, "city": "New York"}

# %%
aux={'one':js.Series([1,2,3],index=['apple','ball','clock']),
     'two':js.Series([10,20,30],index=['pineapple','watermelon','banana']),}

# %%
aux
# Out:
# {'one': apple    1
#  ball     2
#  clock    3
#  dtype: int64,
#  'two': pineapple     10
#  watermelon    20
#  banana        30
#  dtype: int64}

# %%
df=js.DataFrame(aux)

# %%
df.shape
# Out:
# (6, 2)

# %%
df.index
# Out:
# Index(['apple', 'ball', 'banana', 'clock', 'pineapple', 'watermelon'], dtype='object')

# %%
df.columns
# Out:
# Index(['one', 'two'], dtype='object')

# %%
df['three']=df['one']*df['two']
df['four']=df['one']+df['two']
df['five']=df['one']-df['two']
df['six']=df['one']/df['two']
df
# Out:
#             one   two  five  six  three  four
# apple       1.0   NaN   NaN  NaN    NaN   NaN
# ball        2.0   NaN   NaN  NaN    NaN   NaN
# banana      NaN  30.0   NaN  NaN    NaN   NaN
# clock       3.0   NaN   NaN  NaN    NaN   NaN
# pineapple   NaN  10.0   NaN  NaN    NaN   NaN
# watermelon  NaN  20.0   NaN  NaN    NaN   NaN

# %%
df['filtro']=df['one']>=2
df
# Out:
#             one   two  five  six  three  four  filtro
# apple       1.0   NaN   NaN  NaN    NaN   NaN   False
# ball        2.0   NaN   NaN  NaN    NaN   NaN    True
# banana      NaN  30.0   NaN  NaN    NaN   NaN   False
# clock       3.0   NaN   NaN  NaN    NaN   NaN    True
# pineapple   NaN  10.0   NaN  NaN    NaN   NaN   False
# watermelon  NaN  20.0   NaN  NaN    NaN   NaN   False

# %%
del df['three']
df
# Out:
#             one   two  five  six  four  filtro
# apple       1.0   NaN   NaN  NaN   NaN   False
# ball        2.0   NaN   NaN  NaN   NaN    True
# banana      NaN  30.0   NaN  NaN   NaN   False
# clock       3.0   NaN   NaN  NaN   NaN    True
# pineapple   NaN  10.0   NaN  NaN   NaN   False
# watermelon  NaN  20.0   NaN  NaN   NaN   False

# %%
del df['filtro']
df
# Out:
#             one   two  five  six  four
# apple       1.0   NaN   NaN  NaN   NaN
# ball        2.0   NaN   NaN  NaN   NaN
# banana      NaN  30.0   NaN  NaN   NaN
# clock       3.0   NaN   NaN  NaN   NaN
# pineapple   NaN  10.0   NaN  NaN   NaN
# watermelon  NaN  20.0   NaN  NaN   NaN

# %%
df2=df.pop('four')

# %%
df
# Out:
#             one   two  five  six
# apple       1.0   NaN   NaN  NaN
# ball        2.0   NaN   NaN  NaN
# banana      NaN  30.0   NaN  NaN
# clock       3.0   NaN   NaN  NaN
# pineapple   NaN  10.0   NaN  NaN
# watermelon  NaN  20.0   NaN  NaN

# %% [markdown]
# DATASET FROM GITHUB

# %%
tags=js.read_csv('https://raw.githubusercontent.com/ChicagoBoothML/DATA___MovieLens___20M/master/tags.csv')
ratings=js.read_csv('https://raw.githubusercontent.com/ChicagoBoothML/DATA___MovieLens___20M/master/ratings01.csv')
movies = js.read_csv('https://raw.githubusercontent.com/ChicagoBoothML/DATA___MovieLens___20M/master/movies.csv')

# %%
tags.shape
# Out:
# (465564, 4)

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
tags[:10]
# Out:
#    userId  movieId               tag   timestamp
# 0      18     4141       Mark Waters  1240597180
# 1      65      208         dark hero  1368150078
# 2      65      353         dark hero  1368150079
# 3      65      521     noir thriller  1368149983
# 4      65      592         dark hero  1368150078
# 5      65      668         bollywood  1368149876
# 6      65      898  screwball comedy  1368150160
# 7      65     1248     noir thriller  1368149983
# 8      65     1391              mars  1368150055
# 9      65     1617          neo-noir  1368150217

# %%
print(tags['tag'][:10])
# Out:
# 0         Mark Waters
# 1           dark hero
# 2           dark hero
# 3       noir thriller
# 4           dark hero
# 5           bollywood
# 6    screwball comedy
# 7       noir thriller
# 8                mars
# 9            neo-noir
# Name: tag, dtype: object

# %%
movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# ...

# %%
tags.head(10)
# Out:
#    userId  movieId               tag   timestamp
# 0      18     4141       Mark Waters  1240597180
# 1      65      208         dark hero  1368150078
# 2      65      353         dark hero  1368150079
# 3      65      521     noir thriller  1368149983
# 4      65      592         dark hero  1368150078
# 5      65      668         bollywood  1368149876
# 6      65      898  screwball comedy  1368150160
# 7      65     1248     noir thriller  1368149983
# 8      65     1391              mars  1368150055
# 9      65     1617          neo-noir  1368150217

# %%
ratings.head(25)
# Out:
#     userId  movieId  rating   timestamp
# 0        1        2     3.5  1112486027
# 1        1       29     3.5  1112484676
# 2        1       32     3.5  1112484819
# 3        1       47     3.5  1112484727
# 4        1       50     3.5  1112484580
# 5        1      112     3.5  1094785740
# 6        1      151     4.0  1094785734
# 7        1      223     4.0  1112485573
# 8        1      253     4.0  1112484940
# 9        1      260     4.0  1112484826
# 10       1      293     4.0  1112484703
# 11       1      296     4.0  1112484767
# 12       1      318     4.0  1112484798
# 13       1      337     3.5  1094785709
# 14       1      367     3.5  1112485980
# 15       1      541     4.0  1112484603
# 16       1      589     3.5  1112485557
# 17       1      593     3.5  1112484661
# 18       1      653     3.0  1094785691
# 19       1      919     3.5  1094785621
# 20       1      924     3.5  1094785598
# 21       1     1009     3.5  1112486013
# ...

# %%
ratings.tail(10)
# Out:
#          userId  movieId  rating   timestamp
# 1999990   13567    54004     3.5  1262994633
# 1999991   13567    58154     4.0  1262994642
# 1999992   13567    58559     5.0  1262994213
# 1999993   13567    59333     3.5  1262994526
# 1999994   13567    59369     4.0  1262764264
# 1999995   13567    59725     3.5  1262994714
# 1999996   13567    63062     5.0  1262764337
# 1999997   13567    64957     5.0  1262764172
# 1999998   13567    65216     4.5  1262994367
# 1999999   13567    66203     4.0  1262994418
